# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class Problema(object):
    pass

class BuscaLocal(object):
    pass

class Estado(object):
    def __init__(self, valor):
        self.valor = valor

class EstadoPSVM(Estado):
    def __init__(self, valor, e, d):
        super(EstadoPSVM, self).__init__(valor)
        self.e = e
        self.d = d
        
class ProblemaSubVetorMaximo(Problema):
    
    @classmethod
    def from_aleatorio(cls, n_elementos, e_inicial=None, d_inicial=None):
        cls.vetor = np.random.randint(-500,500,(n_elementos))
        if not e_inicial:
            e = np.random.randint(0, n_elementos-1)
            d = np.random.randint(e, n_elementos)
        else:
            e = e_inicial
            d = d_inicial
        valor_ini = ProblemaSubVetorMaximo.__valor_solucao(cls.vetor,e,d)
        cls.estado_inicial = EstadoPSVM(valor_ini, e, d)
        return cls()
    
    @classmethod
    def from_vetor(cls, vetor, e_inicial, d_inicial):
        cls.vetor = vetor
        cls.estado_inicial = EstadoPSVM(ProblemaSubVetorMaximo.__valor_solucao(vetor,e_inicial, d_inicial), e_inicial, d_inicial)
        return cls()
        
    @staticmethod
    def __valor_solucao(v, e, d):
        return np.sum(v[e:d+1])
    
    def valor_solucao(self, e, d):
        return ProblemaSubVetorMaximo.__valor_solucao(self.vetor, e, d)
    
    def vizinhos(self, estado):
        vizs = []
        e = estado.e
        d = estado.d
        for i in [e-1,e,e+1]:
            if (i < 0) or (i >= self.vetor.shape[0]):
                continue
            for j in [d-1,d,d+1]:
                if (j < 0) or (j >= self.vetor.shape[0]):
                    continue
                vizs.append(EstadoPSVM(self.valor_solucao(i,j), i, j))
        return vizs
        
class HillClimbingBL(object):
    
    def __init__(self):
        pass
    
    def buscar(self, problema):
        atual = problema.estado_inicial
        while True:
            vizinho = max(problema.vizinhos(atual), key=lambda x: x.valor)
            vzs = problema.vizinhos(atual)
            print_vizinhos(vzs)
            if vizinho.valor <= atual.valor:
                return atual
            atual = vizinho

def print_vizinhos(estados):
    print('Vizinhos')
    for e in estados:
        print('\te: %d, d: %d, valor: %d' % (e.e, e.d, e.valor))
            
#p = ProblemaSubVetorMaximo.from_aleatorio(10)

v = np.array([13, -3, -25, 20, -3, -16, -23, 18, 20, -7, 12, -5, -22, 15, -4, 7])
p = ProblemaSubVetorMaximo.from_vetor(v, 5, 14)
hc = HillClimbingBL()

solucao = hc.buscar(p)

print(p.vetor)
print (p.estado_inicial.e, p.estado_inicial.d, p.estado_inicial.valor)

print(solucao.valor, solucao.e, solucao.d)
# Out:
# Vizinhos
# 	e: 4, d: 13, valor: -11
# 	e: 4, d: 14, valor: -15
# 	e: 4, d: 15, valor: -8
# 	e: 5, d: 13, valor: -8
# 	e: 5, d: 14, valor: -12
# 	e: 5, d: 15, valor: -5
# 	e: 6, d: 13, valor: 8
# 	e: 6, d: 14, valor: 4
# 	e: 6, d: 15, valor: 11
# Vizinhos
# 	e: 5, d: 14, valor: -12
# 	e: 5, d: 15, valor: -5
# 	e: 6, d: 14, valor: 4
# 	e: 6, d: 15, valor: 11
# 	e: 7, d: 14, valor: 27
# 	e: 7, d: 15, valor: 34
# Vizinhos
# 	e: 6, d: 14, valor: 4
# 	e: 6, d: 15, valor: 11
# 	e: 7, d: 14, valor: 27
# 	e: 7, d: 15, valor: 34
# 	e: 8, d: 14, valor: 9
# 	e: 8, d: 15, valor: 16
# [ 13  -3 -25  20  -3 -16 -23  18  20  -7  12  -5 -22  15  -4   7]
# (5, 14, -12)
# (34, 7, 15)
